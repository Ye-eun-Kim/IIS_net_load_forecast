# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./processed_data/netload/RISE_all_interpolated.csv',index_col=0, header=0)
display(df)
# Out:
#             0      1      2      3      4      5      6      7       8  \
# 210101  903.5  886.1  906.2  881.3  900.3  885.2  885.6  867.1   894.6
# 210102  845.3  852.8  854.3  797.8  806.9  795.0  802.0  833.8   823.8
# 210103  874.1  894.2  910.5  882.1  911.1  876.2  854.1  832.9   837.5
# 210104  879.6  906.7  902.6  866.7  821.9  869.8  853.7  893.9  1063.9
# 210105  925.6  936.7  882.7  894.6  864.2  859.1  853.7  891.3   957.4
# ...       ...    ...    ...    ...    ...    ...    ...    ...     ...
# 211227  862.1  868.6  836.0  849.5  886.9  861.9  888.2  896.7  1085.6
# 211228  885.6  890.9  859.7  875.7  868.3  853.8  850.5  868.5   958.5
# 211229  847.5  877.3  824.7  813.5  836.8  774.4  809.9  853.0   976.3
# 211230  864.7  841.4  788.1  812.6  776.7  801.0  851.0  851.2   937.6
# 211231  864.7  841.4  788.1  812.6  776.7  801.0  851.0  851.2   937.6
#
#              9  ...      15      16      17      18      19      20     21  \
# ...

# %%
# plot graph every column of dataframe
# check 210111-210124


plt.xticks = plt.xticks


df_1 = df.iloc[10:24, :]
date_list = np.array(df_1.index).astype(str)


for i in range(0, 24):
    print('This is the ', i, 'th graph')
    fig = plt.figure(figsize=(10, 2.5))
    ax = plt.axes()
    col = df_1.iloc[:,i]
    ax.plot(date_list, col)
    ax.set_xticks(range(len(date_list)))
    ax.set_xticklabels(date_list, rotation = 45)
    plt.show()
# Out:
# This is the  0 th graph
# This is the  1 th graph
# This is the  2 th graph
# This is the  3 th graph
# This is the  4 th graph
# This is the  5 th graph
# This is the  6 th graph
# This is the  7 th graph
# This is the  8 th graph
# This is the  9 th graph
# This is the  10 th graph
# This is the  11 th graph
# This is the  12 th graph
# This is the  13 th graph
# This is the  14 th graph
# This is the  15 th graph
# This is the  16 th graph
# This is the  17 th graph
# This is the  18 th graph
# This is the  19 th graph
# This is the  20 th graph
# This is the  21 th graph
# This is the  22 th graph
# This is the  23 th graph

# %%
len(col)
# Out:
# 14

# %%
df.iloc[[17]]
# Out:
#             0      1      2      3      4      5      6      7       8  \
# 210118  937.7  917.5  931.1  925.5  920.7  927.3  910.1  932.0  1031.9
#
#              9  ...     15     16      17      18      19      20      21  \
# 210118  1020.5  ...  952.4  967.5  1021.2  1053.8  1014.3  1058.1  1011.4
#
#             22      23  load_flag
# 210118  1001.7  1003.1          0
#
# [1 rows x 25 columns]
